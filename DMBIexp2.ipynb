# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sklearn
import sklearn.model_selection
from pandas.core.frame import DataFrame
data = pd.read_csv('supermarket_sales.csv')
#data.info()
df = pd.read_table("supermarket_sales.csv",delimiter=",")
X = df.iloc[:,[7]].values
y= df.iloc[:,[16]].values

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
X[:,0] = le.fit_transform(X[:,0])

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 0)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9524/563606052.py in <module>
#       1 from sklearn.model_selection import train_test_split
# ----> 2 X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 0)
#
# ~\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\model_selection\_split.py in train_test_split(test_size, train_size, random_state, shuffle, stratify, *arrays)
#    2415         raise ValueError("At least one array required as input")
#    2416
# -> 2417     arrays = indexable(*arrays)
#    2418
#    2419     n_samples = _num_samples(arrays[0])
#
# ~\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\validation.py in indexable(*iterables)
#     376
#     377     result = [_make_indexable(X) for X in iterables]
# --> 378     check_consistent_length(*result)
#     379     return result
#     380
#
# ~\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\validation.py in check_consistent_length(*arrays)
#     330     uniques = np.unique(lengths)
#     331     if len(uniques) > 1:
# --> 332         raise ValueError(
#     333             "Found input variables with inconsistent numbers of samples: %r"
#     334             % [int(l) for l in lengths]
#
# ValueError: Found input variables with inconsistent numbers of samples: [1000, 750]

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
from sklearn.naive_bayes import GaussianNB
classifier = GaussianNB()
y = y_train.ravel()
y_train = np.array(y).astype(int)
classifier.fit(X_train, y_train)
y_pred = classifier.predict(X_test)
y_test
# Out:
# array([[ 6.6],
#        [ 5. ],
#        [ 4.5],
#        [ 8.6],
#        [ 4. ],
#        [ 6.7],
#        [ 7.7],
#        [ 8.7],
#        [ 9.6],
#        [ 7.6],
#        [ 8.5],
#        [ 5.6],
#        [ 4.1],
#        [ 4.9],
#        [ 7.7],
#        [ 8.2],
#        [ 8.8],
#        [ 8.8],
#        [ 5.7],
#        [ 5.7],
#        [ 4.5],
#        [ 6.2],
#        [ 5.5],
#        [ 9.7],
#        [ 7.5],
#        [ 5.6],
#        [ 9.5],
#        [ 9.9],
#        [ 5.6],
#        [ 9.6],
#        [ 8.7],
#        [ 9.1],
#        [ 4.2],
#        [ 4. ],
#        [ 5.5],
#        [ 8.1],
#        [ 7.1],
#        [ 5.6],
#        [ 8.7],
#        [ 9.5],
#        [ 6.5],
#        [ 4.4],
#        [ 5. ],
#        [ 7.8],
#        [ 8.4],
#        [ 8.8],
#        [ 6. ],
#        [ 8.1],
#        [ 7.3],
#        [ 7.7],
#        [ 9.1],
#        [ 7.5],
#        [ 5.7],
#        [ 6.4],
#        [ 4.3],
#        [ 8. ],
#        [ 8.8],
#        [ 6.3],
#        [ 6.2],
#        [ 8.4],
#        [ 4.1],
#        [ 4. ],
#        [ 9.1],
#        [ 9.8],
#        [ 6.6],
#        [ 4.9],
#        [ 7.9],
#        [ 7.2],
#        [ 7.2],
#        [ 5.8],
#        [ 6. ],
#        [ 7.7],
#        [ 8.5],
#        [ 6.8],
#        [ 5.2],
#        [ 7.8],
#        [ 6.6],
#        [ 5.5],
#        [ 4.5],
#        [ 9.4],
#        [ 5.6],
#        [ 4.5],
#        [ 6. ],
#        [ 7.4],
#        [ 4.2],
#        [ 9.5],
#        [ 4.9],
#        [ 9.1],
#        [ 6.2],
#        [ 5.9],
#        [ 4.8],
#        [ 7.1],
#        [ 6.6],
#        [ 9.6],
#        [ 8.5],
#        [ 6.6],
#        [ 5.5],
#        [ 4.2],
#        [ 6. ],
#        [ 5.5],
#        [ 9. ],
#        [ 9.9],
#        [ 5.8],
#        [ 4.2],
#        [ 4.9],
#        [ 6. ],
#        [ 7.7],
#        [ 9.7],
#        [ 7.8],
#        [ 6.5],
#        [ 4.1],
#        [ 9.5],
#        [ 7.7],
#        [ 5. ],
#        [ 9. ],
#        [ 5.8],
#        [ 4.9],
#        [ 9.9],
#        [ 9.8],
#        [ 7.6],
#        [ 8.3],
#        [ 6. ],
#        [ 4.2],
#        [ 5.3],
#        [10. ],
#        [ 5.9],
#        [ 5.2],
#        [ 8.5],
#        [ 5.9],
#        [ 5.2],
#        [ 5.5],
#        [ 6.7],
#        [ 9.5],
#        [ 6. ],
#        [ 8.4],
#        [ 6.8],
#        [ 4.4],
#        [ 7.2],
#        [ 9.3],
#        [ 4. ],
#        [ 7.2],
#        [ 4.2],
#        [ 7.7],
#        [ 4.2],
#        [ 5.7],
#        [ 5. ],
#        [ 9.9],
#        [ 4.3],
#        [ 6.5],
#        [ 7.5],
#        [ 9.7],
#        [ 4.8],
#        [ 9.6],
#        [ 4.5],
#        [ 7. ],
#        [ 4.5],
#        [ 6.2],
#        [ 8. ],
#        [ 7. ],
#        [ 6. ],
#        [ 7.3],
#        [ 4.3],
#        [ 6.1],
#        [ 6.6],
#        [ 6.8],
#        [ 9.4],
#        [ 5.5],
#        [ 5.7],
#        [ 5.5],
#        [ 8.3],
#        [ 7.3],
#        [ 4.3],
#        [ 9.5],
#        [ 7.7],
#        [ 8.7],
#        [ 8.6],
#        [ 5.6],
#        [ 6.3],
#        [ 6.7],
#        [ 8. ],
#        [ 6.3],
#        [ 6.6],
#        [ 4.5],
#        [ 5.2],
#        [ 8.4],
#        [ 5.2],
#        [ 8.1],
#        [ 7.6],
#        [ 6.3],
#        [ 5.4],
#        [ 5.4],
#        [ 4.1],
#        [ 9. ],
#        [ 4.1],
#        [ 7.7],
#        [ 9.4],
#        [ 7.9],
#        [ 8.3],
#        [ 5.1],
#        [ 4.8],
#        [ 4.3],
#        [ 5.4],
#        [ 5.5],
#        [ 6.5],
#        [ 9.6],
#        [ 9.2],
#        [ 5. ],
#        [ 9.8],
#        [ 9.7],
#        [ 6.9],
#        [ 4.3],
#        [ 7.2],
#        [ 4.7],
#        [ 8.9],
#        [ 4.2],
#        [ 8.8],
#        [ 6. ],
#        [ 9.3],
#        [ 7.9],
#        [ 9.8],
#        [ 4.2],
#        [ 9.8],
#        [ 6.4],
#        [ 6.9],
#        [ 7.8],
#        [ 5.9],
#        [ 4.5],
#        [ 5.9],
#        [ 8.6],
#        [ 7. ],
#        [ 6.7],
#        [ 4.7],
#        [ 4.9],
#        [ 6.6],
#        [10. ],
#        [ 6. ],
#        [ 6.5],
#        [ 5.7],
#        [ 4.1],
#        [ 7.7],
#        [ 7.4],
#        [ 7. ],
#        [ 6.8],
#        [ 7.1],
#        [ 6. ],
#        [ 6.1],
#        [ 9.3],
#        [ 7.4],
#        [ 6.7],
#        [ 6.6]])

# %%
y_pred
# Out:
# array([8, 8, 6, 7, 6, 8, 6, 6, 8, 6, 6, 7, 7, 6, 6, 8, 8, 8, 8, 8, 8, 8,
#        7, 6, 7, 6, 6, 7, 8, 7, 6, 7, 8, 6, 6, 8, 7, 8, 6, 8, 6, 8, 8, 8,
#        8, 8, 7, 8, 6, 7, 6, 7, 6, 7, 8, 6, 8, 7, 8, 6, 8, 8, 8, 8, 6, 6,
#        6, 8, 6, 6, 8, 6, 8, 7, 6, 7, 8, 6, 6, 6, 6, 8, 7, 8, 8, 8, 7, 6,
#        7, 6, 7, 6, 8, 8, 7, 6, 8, 8, 6, 7, 8, 7, 8, 7, 7, 8, 6, 8, 8, 8,
#        7, 6, 8, 6, 6, 6, 6, 7, 8, 8, 8, 6, 8, 6, 6, 6, 7, 7, 7, 6, 8, 8,
#        6, 8, 7, 6, 7, 6, 8, 6, 8, 8, 6, 8, 8, 6, 7, 7, 6, 6, 6, 7, 7, 7,
#        6, 7, 8, 6, 6, 8, 6, 6, 6, 6, 8, 6, 8, 8, 8, 6, 8, 6, 7, 8, 8, 7,
#        8, 6, 6, 7, 7, 8, 7, 6, 8, 6, 6, 8, 6, 7, 8, 8, 8, 8, 7, 7, 6, 6,
#        8, 6, 8, 6, 7, 6, 8, 6, 8, 7, 6, 6, 8, 6, 8, 7, 8, 6, 8, 8, 6, 6,
#        6, 6, 6, 6, 7, 8, 8, 7, 6, 8, 6, 6, 8, 6, 8, 7, 6, 6, 6, 8, 8, 8,
#        7, 6, 8, 6, 8, 8, 8, 7])

# %%
from sklearn.metrics import confusion_matrix,accuracy_score
y_test_arg=np.argmax(y_test,axis=1)
y_pred = np.argmax(classifier.predict(y_test))
print('Confusion Matrix')
print(confusion_matrix(y_test_arg, y_pred))
# Out:
# Confusion Matrix
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9524/2869209270.py in <module>
#       3 y_pred = np.argmax(classifier.predict(y_test))
#       4 print('Confusion Matrix')
# ----> 5 print(confusion_matrix(y_test_arg, y_pred))
#
# ~\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py in confusion_matrix(y_true, y_pred, labels, sample_weight, normalize)
#     305     (0, 2, 1, 1)
#     306     """
# --> 307     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#     308     if y_type not in ("binary", "multiclass"):
#     309         raise ValueError("%s is not supported" % y_type)
#
# ~\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py in _check_targets(y_true, y_pred)
#      82     y_pred : array or indicator matrix
#      83     """
# ---> 84     check_consistent_length(y_true, y_pred)
#      85     type_true = type_of_target(y_true)
#      86     type_pred = type_of_target(y_pred)
#
# ~\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\validation.py in check_consistent_length(*arrays)
#     327     """
#     328
# --> 329     lengths = [_num_samples(X) for X in arrays if X is not None]
#     330     uniques = np.unique(lengths)
#     331     if len(uniques) > 1:
#
# ~\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\validation.py in <listcomp>(.0)
#     327     """
#     328
# --> 329     lengths = [_num_samples(X) for X in arrays if X is not None]
#     330     uniques = np.unique(lengths)
#     331     if len(uniques) > 1:
#
# ~\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\validation.py in _num_samples(x)
#     267     if hasattr(x, "shape") and x.shape is not None:
#     268         if len(x.shape) == 0:
# --> 269             raise TypeError(
#     270                 "Singleton array %r cannot be considered a valid collection." % x
#     271             )
#
# TypeError: Singleton array 1 cannot be considered a valid collection.

# %%
#print("Naive Bayes score: ",classifier.score(X_test, y_test))
